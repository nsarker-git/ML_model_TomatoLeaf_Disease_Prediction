# %%
# !pip install tensorflow

# %%
# !pip install pillow

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
# import the libraries as shown below
import tensorflow

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3
#from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
#import matplotlib.pyplot as plt

# %%
# re-size all the images to this
IMAGE_SIZE = [224, 224]

train_path = 'dataset/train'
valid_path = 'dataset/test'

# %%
# Import the inception v3 library as shown below and add preprocessing layer to the front of VGG
# Here we will be using imagenet weights
# top = false means first layer and last layer will not be used

inception = InceptionV3(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
# don't train existing weights
for layer in inception.layers:
    layer.trainable = False

# %%
  # useful for getting number of output classes
folders = glob('dataset/train/*')

# %%
#checking length of folders to know the number of classes
folders
# Out:
# ['dataset/train\\Tomato___Bacterial_spot',
#  'dataset/train\\Tomato___Early_blight',
#  'dataset/train\\Tomato___healthy',
#  'dataset/train\\Tomato___Late_blight',
#  'dataset/train\\Tomato___Leaf_Mold',
#  'dataset/train\\Tomato___Septoria_leaf_spot',
#  'dataset/train\\Tomato___Spider_mites Two-spotted_spider_mite',
#  'dataset/train\\Tomato___Target_Spot',
#  'dataset/train\\Tomato___Tomato_mosaic_virus',
#  'dataset/train\\Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %%
# layers - you can add more if you want
# flatenning the output of inception layer
x = Flatten()(inception.output)

# %%
# custom no of length of folders saying how many output node needed, dense used
# softmax used for mupultiple categories

#prediction = Dense(len(folders), activation='softmax')(x)
prediction = Dense(len(folders), activation='softmax')(x)

# create a model object
model = Model(inputs=inception.input, outputs=prediction)

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 111, 111, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 111, 111, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 111, 111, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 109, 109, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 109, 109, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
# ...

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# Use the Image Data Generator to import the images from the dataset
# data augmentation part for train data only

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
# scale-down test data 
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory('dataset/train',
                                                 target_size = (224, 224),
                                                 batch_size = 16,
                                                 class_mode = 'categorical')
# Out:
# Found 18345 images belonging to 10 classes.

# %%
test_set = test_datagen.flow_from_directory('dataset/test',
                                            target_size = (224, 224),
                                            batch_size = 16,
                                            class_mode = 'categorical')
# Out:
# Found 4585 images belonging to 10 classes.

# %%
# fit the model
# Run the cell. It will take some time to execute
r = model.fit(
  training_set,
  validation_data=test_set,
  epochs=10,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# Epoch 1/10
# 1147/1147 [==============================] - 658s 571ms/step - loss: 3.9487 - accuracy: 0.6866 - val_loss: 3.3159 - val_accuracy: 0.7612
# Epoch 2/10
# 1147/1147 [==============================] - 663s 577ms/step - loss: 3.5615 - accuracy: 0.7863 - val_loss: 2.6127 - val_accuracy: 0.8284
# Epoch 3/10
# 1147/1147 [==============================] - 632s 550ms/step - loss: 3.4580 - accuracy: 0.8146 - val_loss: 4.8338 - val_accuracy: 0.7880
# Epoch 4/10
# 1147/1147 [==============================] - 580s 504ms/step - loss: 3.2725 - accuracy: 0.8357 - val_loss: 3.7223 - val_accuracy: 0.8166
# Epoch 5/10
# 1147/1147 [==============================] - 595s 518ms/step - loss: 3.1857 - accuracy: 0.8529 - val_loss: 3.2602 - val_accuracy: 0.8465
# Epoch 6/10
# 1147/1147 [==============================] - 627s 545ms/step - loss: 2.9819 - accuracy: 0.8629 - val_loss: 3.1437 - val_accuracy: 0.8591
# Epoch 7/10
# ...

# %%
import pickle
#open a file where to store the data in write byte mode
file = open('model_inception.pkl', 'wb')

#dump information to that file
pickle.dump(r, file)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 94). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://7c8af7f1-2877-44b4-8cd4-a22688b84dc1/assets
# INFO:tensorflow:Assets written to: ram://7c8af7f1-2877-44b4-8cd4-a22688b84dc1/assets

# %%
# save it as a h5 file


from tensorflow.keras.models import load_model

model.save('model_inception.h5')

# %%
y_pred = model.predict(test_set)
# Out:
# 287/287 [==============================] - 217s 642ms/step

# %%
import numpy as np
y_pred = np.argmax(y_pred, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 y_pred = np.argmax(y_pred, axis=1)
#
# File <__array_function__ internals>:180, in argmax(*args, **kwargs)
#
# File ~\anaconda3\envs\cottond\lib\site-packages\numpy\core\fromnumeric.py:1216, in argmax(a, axis, out, keepdims)
#    1129 """
#    1130 Returns the indices of the maximum values along an axis.
#    1131
#    (...)
#    1213 (2, 1, 4)
#    1214 """
#    1215 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1216 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File ~\anaconda3\envs\cottond\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
# ...

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
model=load_model('model_inception.h5')

# %%
img_data

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')
